# %%
import pandas as pd
df = pd.read_csv('amazon.csv')

print(df.columns)
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
import

# %%
import pandas as pd
df = pd.read_csv('amazon.csv')

print(df.tail(10))
# Out:
#       product_id                                       product_name  \
# 1455  B00GHL8VP2  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 1456  B0B9JZW1SQ  4 in 1 Handheld Electric Vegetable Cutter Set,...
# 1457  B00TI8E7BI  Philips HD9306/06 1.5-Litre Electric Kettle (M...
# 1458  B07J9KXQCC  Libra Room Heater for Home, Room Heaters Home ...
# 1459  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1455  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...        ₹3,487.77
# ...

# %%
import pandas as pd
df = pd.read_csv('amazon.csv')

df['Sum'] = df['rating'].mean()

print(df['Sum'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ...

# %%
import pandas as pd
df = pd.read_csv('amazon.csv')

print(df.shape)

df_dropped = df.dropna(how = "any")

df_new['product_id'] = df_new['product_id'].fillna((df_new['product_id'].mean()))

# %%
df = pd.read_csv('amazon.csv')

print(df['rating'].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ...

# %%
df import pandas as pd #clean data
df = pd.read_csv('amazon.csv')

print(df.shape)

df_dropped = df.dropna(how = "any")

df_new['product_id'] = df_new['product_id'].fillna((df_new['product_id'].mean()))

# %%
import pandas as pd
df = pd.read_csv('amazon.csv')

df.groupby(['rating']).mean()
# Out:
# C:\Users\Omen\AppData\Local\Temp\ipykernel_22264\4035623522.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rating']).mean()
# Empty DataFrame
# Columns: []
# Index: [2, 2.3, 2.6, 2.8, 2.9, 3, 3.0, 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4, 4.0, 4.1, 4.2, 4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 5.0, |]

# %%
df = pd.read_csv('amazon.csv')

for i,x in df.iterrows():
    newsum = sum(x['rating'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 df = pd.read_csv('amazon.csv')
#       3 for i,x in df.iterrows():
# ----> 4     newsum = sum(x['rating'])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#print(df['rating'].mean())    
import pandas as pd
df = pd.read_csv('amazon.csv')
avg_discount = (df['discount_percentage'].mean())
print(avg_discount)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ...

# %%
df = pd.read(csv
